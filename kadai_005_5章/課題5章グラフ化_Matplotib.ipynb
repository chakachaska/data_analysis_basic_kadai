# %%
fig, axes = plt.subplots(2, 3, figsize=(12, 8), tight_layout=True)  # 1つの机を作成

# 全部この机（axes）にグラフを置く
axes[0, 0].plot([1, 2, -5, 2])          # 折れ線グラフ
axes[0, 1].plot(np.linspace(0, 10, 100), 2 + 2 * np.sin(2 * np.linspace(0, 10, 100)))  # sin関数
axes[0, 2].hist(np.random.normal(15, 5, 2000), bins=30)  # ヒストグラム
axes[1, 0].scatter(np.random.normal(4, 2, 60), np.random.normal(4, 2, 60))  # 散布図
